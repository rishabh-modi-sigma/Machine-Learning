# %%
import pandas as pd 
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("loan_approval_data.csv")

# %%
df.head()
df.info()
df.isnull().sum
df.describe

# %%
categorial_cols = df.select_dtypes(include=["object"]).columns
numerical_cols = df.select_dtypes(include=["number"]).columns

# %%
df[categorial_cols].head()
df[numerical_cols].head()
# Out:
#    Applicant_ID  Applicant_Income  Coapplicant_Income   Age  Dependents  \
# 0           1.0           17795.0              1387.0  51.0         0.0
# 1           2.0            2860.0              2679.0  46.0         3.0
# 2           3.0            7390.0              2106.0  25.0         2.0
# 3           4.0           13964.0              8173.0  40.0         2.0
# 4           5.0           13284.0              4223.0  31.0         2.0
#
#    Credit_Score  Existing_Loans  DTI_Ratio  Savings  Collateral_Value  \
# 0         637.0             4.0       0.53  19403.0           45638.0
# 1         621.0             2.0       0.30   2580.0           49272.0
# 2         674.0             4.0       0.20  13844.0            6908.0
# 3         579.0             3.0       0.31   9553.0           10844.0
# 4         721.0             1.0       0.29   9386.0           37629.0
#
#    Loan_Amount  Loan_Term
# 0      16619.0       84.0
# 1      38687.0        NaN
# 2      27943.0       72.0
# 3      27819.0       60.0
# 4      12741.0       72.0

# %%
from sklearn.impute import SimpleImputer
num_imp = SimpleImputer(strategy="mean")
df[numerical_cols] = num_imp.fit_transform(df[numerical_cols])

# %%
df[numerical_cols].head()
df[numerical_cols].isnull().sum

# %%
cat_imp = SimpleImputer(strategy="most_frequent")
df[categorial_cols] = cat_imp.fit_transform(df[categorial_cols])

# %%
df[categorial_cols].head()
# Out:
#   Employment_Status Marital_Status Loan_Purpose Property_Area Education_Level  \
# 0          Salaried        Married     Personal         Urban    Not Graduate
# 1          Salaried        Married          Car     Semiurban        Graduate
# 2          Salaried         Single     Business         Urban        Graduate
# 3          Salaried        Married     Business         Rural        Graduate
# 4     Self-employed         Single          Car         Urban        Graduate
#
#    Gender Employer_Category Loan_Approved
# 0  Female           Private            No
# 1    Male           Private            No
# 2  Female        Government           Yes
# 3  Female        Government            No
# 4    Male           Private           Yes

# %%
class_count =
