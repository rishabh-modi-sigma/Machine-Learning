# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("loan_approval_data.csv")

# %%
df.head()
# df.info()
# df.isnull().sum
# df.describe
# Out:
#    Applicant_ID  Applicant_Income  ...  Employer_Category Loan_Approved
# 0           1.0           17795.0  ...            Private            No
# 1           2.0            2860.0  ...            Private            No
# 2           3.0            7390.0  ...         Government           Yes
# 3           4.0           13964.0  ...         Government            No
# 4           5.0           13284.0  ...            Private           Yes
#
# [5 rows x 20 columns]

# %%
categorical_cols = df.select_dtypes(include=["object"]).columns
numerical_cols = df.select_dtypes(include=["number"]).columns

# %%
from sklearn.impute import SimpleImputer
num_imp = SimpleImputer(strategy="mean")
df[numerical_cols] = num_imp.fit_transform(df[numerical_cols])

# %%
print(df[categorical_cols].head())
# Out:
#   Employment_Status Marital_Status  ... Employer_Category Loan_Approved
# 0          Salaried        Married  ...           Private            No
# 1          Salaried        Married  ...           Private            No
# 2          Salaried         Single  ...        Government           Yes
# 3          Salaried        Married  ...        Government            No
# 4     Self-employed         Single  ...           Private           Yes
#
# [5 rows x 8 columns]

# %%
cat_imp = SimpleImputer(strategy="most_frequent")
df[categorical_cols] = cat_imp.fit_transform(df[categorical_cols])

# %%
df.head()
# Out:
#    Applicant_ID  Applicant_Income  Coapplicant_Income Employment_Status   Age  \
# 0           1.0           17795.0              1387.0          Salaried  51.0
# 1           2.0            2860.0              2679.0          Salaried  46.0
# 2           3.0            7390.0              2106.0          Salaried  25.0
# 3           4.0           13964.0              8173.0          Salaried  40.0
# 4           5.0           13284.0              4223.0     Self-employed  31.0
#
#   Marital_Status  Dependents  Credit_Score  Existing_Loans  DTI_Ratio  \
# 0        Married         0.0         637.0             4.0       0.53
# 1        Married         3.0         621.0             2.0       0.30
# 2         Single         2.0         674.0             4.0       0.20
# 3        Married         2.0         579.0             3.0       0.31
# 4         Single         2.0         721.0             1.0       0.29
#
#    Savings  Collateral_Value  Loan_Amount  Loan_Term Loan_Purpose  \
# 0  19403.0           45638.0      16619.0       84.0     Personal
# 1   2580.0           49272.0      38687.0       48.0          Car
# 2  13844.0            6908.0      27943.0       72.0     Business
# 3   9553.0           10844.0      27819.0       60.0     Business
# 4   9386.0           37629.0      12741.0       72.0          Car
#
#   Property_Area Education_Level  Gender Employer_Category Loan_Approved
# 0         Urban    Not Graduate  Female           Private            No
# 1     Semiurban        Graduate    Male           Private            No
# 2         Urban        Graduate  Female        Government           Yes
# 3         Rural        Graduate  Female        Government            No
# 4         Urban        Graduate    Male           Private           Yes

# %%
classes_count = df["Loan_Approved"].value_counts()
plt.pie(classes_count,labels=["No","Yes"],autopct="%1.1f%%",wedgeprops={
    "edgecolor":"black",
    "linewidth": 1
})
plt.title("Is Loan approved or not")
# Out:
# Text(0.5, 1.0, 'Is Loan approved or not')

# %%
gender_cnt = df["Gender"].value_counts()
ax = sns.barplot(gender_cnt)
ax.bar_label(ax.containers[0])

ent_cnt = df["Education_Level"].value_counts()
ax = sns.barplot(ent_cnt)
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '621'), Text(0, 0, '379')]

# %%
sns.histplot(
    data = df,
    x = "Applicant_Income",
    bins = 20
)
# Out:
# <Axes: xlabel='Applicant_Income', ylabel='Count'>

# %%
sns.histplot(
    data = df,
    x = "Coapplicant_Income",
    bins = 20
)
# Out:
# <Axes: xlabel='Coapplicant_Income', ylabel='Count'>

# %%
# marital_status

mar_cnt = df["Marital_Status"].value_counts()
ax = sns.barplot(mar_cnt)
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '643'), Text(0, 0, '357')]

# %%
plt.figure(figsize =(8,5))
sns.boxplot(
    data = df,
    x="Loan_Approved",
    y="Applicant_Income",
    palette="Set2"
)
plt.title("Applicant_Income vs Loan_Approved")
plt.show()
# Out:
# C:\Users\BHAVESH\AppData\Local\Temp\ipykernel_17456\2660539698.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(

# %%
df.head()
# Out:
#    Applicant_ID  Applicant_Income  ...  Employer_Category Loan_Approved
# 0           1.0           17795.0  ...            Private            No
# 1           2.0            2860.0  ...            Private            No
# 2           3.0            7390.0  ...         Government           Yes
# 3           4.0           13964.0  ...         Government            No
# 4           5.0           13284.0  ...            Private           Yes
#
# [5 rows x 20 columns]

# %%
fig , axes = plt.subplots(2,2, figsize=(10,8))

sns.boxplot(
    ax = axes[0,0],
    data = df,
    x = "Loan_Approved",
    y = "Applicant_Income",
    palette=["#ff9999", "#99ff99"]
)

sns.boxplot(
    ax = axes[0,1],
    data = df,
    x = "Loan_Approved",
    y = "Credit_Score",
      palette=["#66b3ff", "#ffcc99"]
)

sns.boxplot(
    ax = axes[1,0],
    data = df,
    x = "Loan_Approved",
    y = "DTI_Ratio",
    palette=["#c2c2f0", "#ffb3e6"]
)

sns.boxplot(
    ax = axes[1,1],
    data = df,
    x = "Loan_Approved",
    y = "Savings",
    palette=["#a6d854", "#ffd92f"]
)
# Out:
# C:\Users\BHAVESH\AppData\Local\Temp\ipykernel_17456\883421371.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(
# C:\Users\BHAVESH\AppData\Local\Temp\ipykernel_17456\883421371.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(
# C:\Users\BHAVESH\AppData\Local\Temp\ipykernel_17456\883421371.py:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(
# C:\Users\BHAVESH\AppData\Local\Temp\ipykernel_17456\883421371.py:27: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(
# <Axes: xlabel='Loan_Approved', ylabel='Savings'>

# %%
df.head()
# Out:
#    Applicant_ID  Applicant_Income  ...  Employer_Category Loan_Approved
# 0           1.0           17795.0  ...            Private            No
# 1           2.0            2860.0  ...            Private            No
# 2           3.0            7390.0  ...         Government           Yes
# 3           4.0           13964.0  ...         Government            No
# 4           5.0           13284.0  ...            Private           Yes
#
# [5 rows x 20 columns]

# %%
sns.histplot(
    data = df,
    x = "Credit_Score",
    hue = "Loan_Approved",
    bins = 20,
    multiple = "dodge",
    palette=["#ff4d4d", "#4CAF50"],
    kde=True
)
# Out:
# <Axes: xlabel='Credit_Score', ylabel='Count'>

# %%
sns.histplot(
    data = df,
    x = "Applicant_Income",
    hue = "Loan_Approved",
    bins = 20 , 
    multiple = "dodge"
)
# Out:
# <Axes: xlabel='Applicant_Income', ylabel='Count'>

# %%
df = df.drop("Applicant_ID", axis=1)

# %%
df.head()
# Out:
#    Applicant_Income  Coapplicant_Income  ... Employer_Category  Loan_Approved
# 0           17795.0              1387.0  ...           Private             No
# 1            2860.0              2679.0  ...           Private             No
# 2            7390.0              2106.0  ...        Government            Yes
# 3           13964.0              8173.0  ...        Government             No
# 4           13284.0              4223.0  ...           Private            Yes
#
# [5 rows x 19 columns]

# %%
df.head()
df.columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Applicant_Income    1000 non-null   float64
#  1   Coapplicant_Income  1000 non-null   float64
#  2   Employment_Status   1000 non-null   object
#  3   Age                 1000 non-null   float64
#  4   Marital_Status      1000 non-null   object
#  5   Dependents          1000 non-null   float64
#  6   Credit_Score        1000 non-null   float64
#  7   Existing_Loans      1000 non-null   float64
#  8   DTI_Ratio           1000 non-null   float64
#  9   Savings             1000 non-null   float64
#  10  Collateral_Value    1000 non-null   float64
#  11  Loan_Amount         1000 non-null   float64
#  12  Loan_Term           1000 non-null   float64
#  13  Loan_Purpose        1000 non-null   object
#  14  Property_Area       1000 non-null   object
#  15  Education_Level     1000 non-null   object
#  16  Gender              1000 non-null   object
#  17  Employer_Category   1000 non-null   object
#  18  Loan_Approved       1000 non-null   object
# dtypes: float64(11), object(8)
# memory usage: 148.6+ KB

# %%
from sklearn.preprocessing import LabelEncoder , OneHotEncoder

le = LabelEncoder()

df["Education_Level"] = le.fit_transform(df["Education_Level"])
df["Loan_Approved"] = le.fit_transform(df["Loan_Approved"])

# %%
df.head()
# Out:
#    Applicant_Income  Coapplicant_Income  ... Employer_Category  Loan_Approved
# 0           17795.0              1387.0  ...           Private              0
# 1            2860.0              2679.0  ...           Private              0
# 2            7390.0              2106.0  ...        Government              1
# 3           13964.0              8173.0  ...        Government              0
# 4           13284.0              4223.0  ...           Private              1
#
# [5 rows x 19 columns]

# %%
cols = ["Employment_Status", "Marital_Status", "Loan_Purpose", "Property_Area", "Gender", "Employer_Category"]

ohe = OneHotEncoder(drop="first", sparse_output=False, handle_unknown="ignore")

encoded = ohe.fit_transform(df[cols])

encoded_df = pd.DataFrame(encoded, columns=ohe.get_feature_names_out(cols), index=df.index)

df = pd.concat([df.drop(columns=cols), encoded_df], axis=1)

# %%
df.head()
# Out:
#    Applicant_Income  ...  Employer_Category_Unemployed
# 0           17795.0  ...                           0.0
# 1            2860.0  ...                           0.0
# 2            7390.0  ...                           0.0
# 3           13964.0  ...                           0.0
# 4           13284.0  ...                           0.0
#
# [5 rows x 28 columns]

# %%
num_cols = df.select_dtypes(include="number")
corr_matrix = num_cols.corr()
plt.figure(figsize=(20,10))
sns.heatmap(
    corr_matrix,
    annot=True,
    fmt=".2f",
    cmap="coolwarm"
)

plt.tight_layout()
plt.show()

# %%
num_cols.corr()["Loan_Approved"].sort_values(ascending=False)
# Out:
# Loan_Approved                      1.000000
# Credit_Score                       0.451175
# Applicant_Income                   0.119796
# Employer_Category_MNC              0.069049
# Loan_Purpose_Personal              0.034043
# Marital_Status_Single              0.030182
# Property_Area_Urban                0.025963
# Collateral_Value                   0.021868
# Coapplicant_Income                 0.004230
# Loan_Purpose_Home                  0.002118
# Employment_Status_Self-employed   -0.001337
# Employer_Category_Private         -0.003347
# Property_Area_Semiurban           -0.012967
# Savings                           -0.013437
# Loan_Purpose_Education            -0.016684
# Employer_Category_Unemployed      -0.021468
# Age                               -0.022343
# Dependents                        -0.023811
# Existing_Loans                    -0.034794
# Employer_Category_Government      -0.039187
# Employment_Status_Salaried        -0.041428
# Employment_Status_Unemployed      -0.044464
# Education_Level                   -0.052920
# Gender_Male                       -0.054342
# Loan_Purpose_Car                  -0.056416
# Loan_Term                         -0.086644
# Loan_Amount                       -0.126499
# DTI_Ratio                         -0.444783
# Name: Loan_Approved, dtype: float64

# %%
x = df.drop("Loan_Approved",axis=1)
y = df["Loan_Approved"]

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Loan_Approved, dtype: int64

# %%
x_train , x_test , y_train , y_test = train_test_split(
    x,y,test_size = 0.2 , random_state = 42
)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
x_test_scaled
# Out:
# array([[ 0.42610546,  0.55091079,  1.19037073, ..., -0.41388776,
#          1.16316   , -0.30723158],
#        [ 1.00971366,  0.58995935,  0.18392964, ..., -0.41388776,
#          1.16316   , -0.30723158],
#        [-0.67557096, -0.54558674,  1.09887608, ..., -0.41388776,
#          1.16316   , -0.30723158],
#        ...,
#        [-0.67980585, -0.10106072,  1.28186537, ..., -0.41388776,
#          1.16316   , -0.30723158],
#        [-0.37650705, -0.97825874, -0.54802752, ..., -0.41388776,
#         -0.85972695, -0.30723158],
#        [-0.73647272, -1.24497436,  0.73289751, ..., -0.41388776,
#          1.16316   , -0.30723158]], shape=(200, 27))

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import f1_score

# Logistic Regression model
log_model = LogisticRegression()
log_model.fit(x_train_scaled, y_train)

# Predictions
y_pred = log_model.predict(x_test_scaled)

# Multiclass-safe f1 score
f1 = f1_score(y_test, y_pred, average='weighted')

print("F1-score :", f1)
# Out:
# F1-score : 0.8646840842442015

# %%
from sklearn.metrics import confusion_matrix , accuracy_score , precision_score , recall_score , f1_score
print("LogisticRegression")
print("precision_score :", precision_score(y_test, y_pred))
print("recall_score :", recall_score(y_test , y_pred))
print("accuracy_matrix :", accuracy_score(y_test , y_pred))
print("f1_score :", f1_score(y_test , y_pred))
print("confusion_matrix :", confusion_matrix(y_test , y_pred))
# Out:
# LogisticRegression
# precision_score : 0.7833333333333333
# recall_score : 0.7704918032786885
# accuracy_matrix : 0.865
# f1_score : 0.7768595041322314
# confusion_matrix : [[126  13]
#  [ 14  47]]

# %%
from sklearn.neighbors import KNeighborsClassifier

knn_model = KNeighborsClassifier(n_neighbors=5)
knn_model.fit(x_train_scaled,y_train)  
y_pred = knn_model.predict(x_test_scaled)

print("KNighborsClassifier")
print("precision_score :", precision_score(y_test,y_pred))
print("recall_score :", recall_score(y_test,y_pred))
print("accuracy_score :", accuracy_score(y_test, y_pred))
print("f1_score :", f1_score(y_test , y_pred))
print("confusion_matrix :", confusion_matrix(y_test , y_pred))
# Out:
# KNighborsClassifier
# precision_score : 0.6274509803921569
# recall_score : 0.5245901639344263
# accuracy_score : 0.76
# f1_score : 0.5714285714285714
# confusion_matrix : [[120  19]
#  [ 29  32]]

# %%
from sklearn.naive_bayes import GaussianNB

nb_model = GaussianNB()
nb_model.fit(x_train_scaled,y_train)
y_pred = nb_model.predict(x_test_scaled)

#Evaluation
print("Naive Bayes model")
print("precision_score :", precision_score(y_test , y_pred))
print("recall_score :", recall_score(y_test, y_pred))
print("accuracy_score :", accuracy_score(y_test , y_pred))
print("f1_score :", f1_score(y_test , y_pred))
print("confusion_matrix :", confusion_matrix(y_test, y_pred))
# Out:
# Naive Bayes model
# precision_score : 0.8035714285714286
# recall_score : 0.7377049180327869
# accuracy_score : 0.865
# f1_score : 0.7692307692307693
# confusion_matrix : [[128  11]
#  [ 16  45]]

# %%
# Feature Engineering

# Add or Tranform Features

df["Dti_Ratio_sq"] = df["DTI_Ratio"] ** 2
df["Credit_Score"] = df["Credit_Score"] ** 2

x = df.drop(columns = ["Loan_Approved","Credit_Score","DTI_Ratio"])
y = df["Loan_Approved"]

# Train test split

x_test,x_train,y_test,y_train = train_test_split(
    x,y,test_size=0.2,random_state=42
)

# Scalling

scaler = StandardScaler()

x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
x_train.head()
# Out:
#      Applicant_Income  ...  Dti_Ratio_sq
# 521           13023.0  ...      0.120592
# 737           15917.0  ...      0.168100
# 740            7560.0  ...      0.336400
# 660           19022.0  ...      0.168100
# 411            4967.0  ...      0.336400
#
# [5 rows x 26 columns]

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_model = KNeighborsClassifier(n_neighbors=5)
knn_model.fit(x_train_scaled,y_train)
y_pred = knn_model.predict(x_test_scaled)

print("precision_score :", precision_score(y_test , y_pred))
print("recall_score :", recall_score(y_test, y_pred))
print("accuracy_score :", accuracy_score(y_test , y_pred))
print("f1_score :", f1_score(y_test , y_pred))
print("confusion_matrix :", confusion_matrix(y_test, y_pred))
# Out:
# precision_score : 0.4021164021164021
# recall_score : 0.3206751054852321
# accuracy_score : 0.6575
# f1_score : 0.3568075117370892
# confusion_matrix : [[450 113]
#  [161  76]]

# %%
from sklearn.naive_bayes import GaussianNB

nb_model = GaussianNB()
nb_model.fit(x_train_scaled,y_train)
y_pred = nb_model.predict(x_test_scaled)

#Evaluation
print("Naive Bayes model")
print("precision_score :", precision_score(y_test , y_pred))
print("recall_score :", recall_score(y_test, y_pred))
print("accuracy_score :", accuracy_score(y_test , y_pred))
print("f1_score :", f1_score(y_test , y_pred))
print("confusion_matrix :", confusion_matrix(y_test, y_pred))
# Out:
# Naive Bayes model
# precision_score : 0.53
# recall_score : 0.6708860759493671
# accuracy_score : 0.72625
# f1_score : 0.5921787709497207
# confusion_matrix : [[422 141]
#  [ 78 159]]
